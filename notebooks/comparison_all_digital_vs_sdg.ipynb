# %% [markdown]
# ### All digital vs All sdg
# all_digital.pkl contains all publications related to digital technologies between 2010 and 2021 from Web of Science
# all_sdg.pkl contains all publications related to Science Development Goals between 2010 and 2021 from Web of Science

# %% [markdown]
# ### First, quick comparison between all_digital and all_digital_europe

# %%
import re

import pandas as pd

# %%
all_digi = pd.read_pickle("../data/output/all_digital.pkl")
all_digi_eu = pd.read_pickle("../data/output/all_digital_europe.pkl")

# %%
filtered_eu_all_digi = all_digi[all_digi["EU"]]
filtered_eu_all_digi
# Out:
#         PT                                                 AU  \
# 0        J             Ondra, V; Sever, IA; Schwingshackl, CW
# 21       J  Friedrich, J; Hinze, C; Renner, A; Verl, A; Le...
# 24       J  Shirazian, S; Kuhs, M; Darwish, S; Croker, D; ...
# 26       J               Lee, HY; Tseng, BH; Wen, TH; Tsao, Y
# 28       J                   Chen, T; Xu, RF; He, YL; Wang, X
# ...     ..                                                ...
# 1253108  J  Hubschwerlen, N; Zhang, KN; Mayer, G; Roger, J...
# 1253109  J          Krulis, M; Skopal, T; Lokoc, J; Beecks, C
# 1253111  J                               Platts, JA; Hill, JG
# 1253117  C              Cebrian, JM; Guerrero, GD; Garcia, JM
# 1253122  J  Herold, C; Mattheisen, M; Lacour, A; Vaitsiakh...
#
#                                                         TI  \
# 0        A method for detection and characterisation of...
# 21       Estimation of stability lobe diagrams in milli...
# ...

# %%
all_digi_eu
# Out:
#        PT                                                 AU  \
# 0       C                              Schaefer, C; Edman, C
# 1       C  Saha, S; Sutrala, AK; Das, AK; Kumar, N; Rodri...
# 2       J   Mohammadzadeh, N; Nogoorani, SD; Munoz-Tapia, JL
# 3       C             Abou El Houda, Z; Khoukhi, L; Hafid, A
# 4       J  Chaintoutis, C; Akriotou, M; Mesaritakis, C; K...
# ...    ..                                                ...
# 371704  J  Wen, ZF; Zhang, C; Shao, GF; Wu, SJ; Atkinson, PM
# 371705  J  Sydes, MR; Barbachano, Y; Bowman, L; Denwood, ...
# 371706  J  Gurdasani, D; Bhatt, S; Costello, A; Denaxas, ...
# 371707  J  Wang, CF; Bendle, JA; Yang, H; Yang, Y; Hardma...
# 371708  J  Nasser, MG; Hosni, EM; Kenawy, MA; Alharbi, SA...
#
#                                                        TI  \
# 0             Transparent Logging with Hyperledger Fabric
# 1       On the Design of Blockchain-Based Access Contr...
# ...

# %%
print(f'focus on EU from full DB = {len(filtered_eu_all_digi): >10}.\nFocus on EU from EU DB = {len(all_digi_eu): >12}\nDifference = {len(filtered_eu_all_digi)-len(all_digi_eu): >22}')
# Out:
# focus on EU from full DB =     375191.
# Focus on EU from EU DB =       371709
# Difference =                   3482

# %% [markdown]
# ## What are these 3500 publications ?

# %%
# filtered_eu_all_digi.drop(columns="EU", inplace=True)
concat = pd.concat([filtered_eu_all_digi, all_digi_eu])

# %%
concat
# Out:
#        PT                                                 AU  \
# 0       J             Ondra, V; Sever, IA; Schwingshackl, CW
# 21      J  Friedrich, J; Hinze, C; Renner, A; Verl, A; Le...
# 24      J  Shirazian, S; Kuhs, M; Darwish, S; Croker, D; ...
# 26      J               Lee, HY; Tseng, BH; Wen, TH; Tsao, Y
# 28      J                   Chen, T; Xu, RF; He, YL; Wang, X
# ...    ..                                                ...
# 371704  J  Wen, ZF; Zhang, C; Shao, GF; Wu, SJ; Atkinson, PM
# 371705  J  Sydes, MR; Barbachano, Y; Bowman, L; Denwood, ...
# 371706  J  Gurdasani, D; Bhatt, S; Costello, A; Denaxas, ...
# 371707  J  Wang, CF; Bendle, JA; Yang, H; Yang, Y; Hardma...
# 371708  J  Nasser, MG; Hosni, EM; Kenawy, MA; Alharbi, SA...
#
#                                                        TI  \
# 0       A method for detection and characterisation of...
# 21      Estimation of stability lobe diagrams in milli...
# ...

# %%
new_concat = concat.drop_duplicates(subset="AB", keep=False)
new_concat
# Out:
#        PT                                                 AU  \
# 244     J  Postans, M; Hodgetts, CJ; Mundy, ME; Jones, DK...
# 463     J  Trihinas, D; Agathocleous, M; Avogian, K; Kata...
# 1330    J                Landrigan, JF; Zhang, FQ; Mirman, D
# 1384    J                             Gazis, IZ; Greinert, J
# 1575    J                Rogers, S; Girolami, M; Polajnar, T
# ...    ..                                                ...
# 363670  J  Burrello, J; Amongero, M; Buffolo, F; Sconfien...
# 365324  J  Erlic, Z; Reel, P; Reel, S; Amar, L; Pecori, A...
# 366702  J  Gomila, RM; Martorell, G; Fraile-Ribot, PA; Do...
# 367618  J  Adusei, YY; Quaye-Ballard, J; Adjaottor, AA; M...
# 371168  J  Tunaligil, V; Meral, G; Dabak, MR; Canbulat, M...
#
#                                                        TI  \
# 244     Interindividual Variation in Fornix Microstruc...
# 463     FlockAI: A Testing Suite for ML-Driven Drone A...
# ...

# %% [markdown]
# ### Now working on the comparison between All_sdg and All_digital

# %%
all_sdg = pd.read_pickle("../data/output/all_sdg_fixed_dst.pkl")
all_sdg.to_csv("../data/output/all_sdg.csv",  header=True, index=False, sep="\t")
# all_sdg.to_parquet("../data/output/all_sdg.parquet")

# All digital
# all_digi.to_csv("../data/output/all_digital.csv",  header=True, index=False, sep="\t")
# all_digi.to_parquet("../data/output/all_digital.parquet")

# %%
all_sdg
# Out:
#         PT                                                 AU  \
# 0        J       Pauw, WP; Castro, P; Pickering, J; Bhasin, S
# 1        C  Morozova, IM; Litvinova, TN; Przhedetskaya, NV...
# 2        J               Hourcade, JC; Dasgupta, D; Ghersi, F
# 3        J                         Larionova, M; Safonkina, E
# 4        J        Kim, DH; Kim, DH; Lee, DH; Park, S; Kim, SI
# ...     ..                                                ...
# 1200662  J                                 Zhang, H; Smith, M
# 1200663  C                                  Zhang, HF; Wu, YZ
# 1200664  C                                  Zhang, J; Chen, S
# 1200665  J                   Zhou, YJ; Dominici, F; Louis, TA
# 1200666  J                                         Zoomers, A
#
#                                                         TI  \
# 0        Conditional nationally determined contribution...
# 1        The Problems of Financing of Entrepreneurship ...
# ...

# %%
all_sdg_dst = all_sdg[all_sdg['DST']].reset_index(drop=True)

# %%
all_sdg_dst
# Out:
#       PT                                                 AU  \
# 0      C               Khan, F; Zhang, B; Khan, S; Chen, SQ
# 1      J  Nasseri, A; Jamshidi, S; Yazdifar, H; Percy, D...
# 2      J         Khalifa, N; Abd Elghany, M; Abd Elghany, M
# 3      J       Emmanuel, O; Ananya, M; Misra, S; Koyuncu, M
# 4      J    Kharal, AY; Khalid, HA; Gastli, A; Guerrero, JM
# ...   ..                                                ...
# 47338  C                Yang, WM; Li, DD; Sun, DR; Liao, QM
# 47339  C                Shaheen, M; Shahbaz, M; Jadoon, KAK
# 47340  J  Wolfson, M; Wallace, SE; Masca, N; Rowe, G; Sh...
# 47341  J                                      Palsdottir, A
# 47342  C               Singh, SR; Murthy, HA; Gonsalves, TA
#
#                                                       TI  \
# 0      TECHNOLOGICAL LEAP FROGGING E-GOVERNMENT THROU...
# 1      Evaluating the performances of over-the-counte...
# 2      Exploratory research on digitalization transfo...
# ...

# %%
df_merge = pd.merge(all_sdg_dst, all_digi.UT, on="UT")
df_merge
# Out:
#       PT                                                 AU  \
# 0      C               Khan, F; Zhang, B; Khan, S; Chen, SQ
# 1      J  Nasseri, A; Jamshidi, S; Yazdifar, H; Percy, D...
# 2      J         Khalifa, N; Abd Elghany, M; Abd Elghany, M
# 3      J       Emmanuel, O; Ananya, M; Misra, S; Koyuncu, M
# 4      J    Kharal, AY; Khalid, HA; Gastli, A; Guerrero, JM
# ...   ..                                                ...
# 46398  C                Yang, WM; Li, DD; Sun, DR; Liao, QM
# 46399  C                Shaheen, M; Shahbaz, M; Jadoon, KAK
# 46400  J  Wolfson, M; Wallace, SE; Masca, N; Rowe, G; Sh...
# 46401  J                                      Palsdottir, A
# 46402  C               Singh, SR; Murthy, HA; Gonsalves, TA
#
#                                                       TI  \
# 0      TECHNOLOGICAL LEAP FROGGING E-GOVERNMENT THROU...
# 1      Evaluating the performances of over-the-counte...
# 2      Exploratory research on digitalization transfo...
# ...

# %%
print(f'all_SDG filtered on DST = {len(all_sdg_dst): >20}\nSDG_DST merged with all digital = {len(df_merge): >12}\nDifference = {len(all_sdg_dst)-len(df_merge): >33}')
# Out:
# all_SDG filtered on DST =                47343
# SDG_DST merged with all digital =        46403
# Difference =                               940

# %%
df_countries = pd.read_excel("../data/countries_full.xls")

# %%
df_countries
# Out:
#                             Country Country ISO3 Country Code  \
# 0                       Afghanistan          AFG            4
# 1                           Albania          ALB            8
# 2                           Algeria          DZA           12
# 3                    American Samoa          ASM           16
# 4                           Andorra          AND           20
# ..                              ...          ...          ...
# 264                           Yemen          YEM          887
# 265                Yemen Democratic          YDR          720
# 266  Yugoslavia, FR (Serbia/Montene          YUG          890
# 267                          Zambia          ZMB          894
# 268                        Zimbabwe          ZWE          716
#
#                                    Long Name         Income Group  \
# 0               Islamic State of Afghanistan           Low income
# 1                        Republic of Albania  Upper middle income
# ...

# %%
df= pd.read_csv("../data/output/csv/all_sdg.csv", sep="\t", encoding='utf-8', index_col=False)

# %%
df
# Out:
#         PT                                                 AU  \
# 0        J       Pauw, WP; Castro, P; Pickering, J; Bhasin, S
# 1        C  Morozova, IM; Litvinova, TN; Przhedetskaya, NV...
# 2        J               Hourcade, JC; Dasgupta, D; Ghersi, F
# 3        J                         Larionova, M; Safonkina, E
# 4        J        Kim, DH; Kim, DH; Lee, DH; Park, S; Kim, SI
# ...     ..                                                ...
# 1200662  J                                 Zhang, H; Smith, M
# 1200663  C                                  Zhang, HF; Wu, YZ
# 1200664  C                                  Zhang, J; Chen, S
# 1200665  J                   Zhou, YJ; Dominici, F; Louis, TA
# 1200666  J                                         Zoomers, A
#
#                                                         TI  \
# 0        Conditional nationally determined contribution...
# 1        The Problems of Financing of Entrepreneurship ...
# ...
