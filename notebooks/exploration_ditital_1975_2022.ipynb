# %%
import pandas as pd

# %%
df = pd.read_pickle("../data/dataframes/digital/digital_1975-2022.pkl")

# %%
df.to_parquet("../data/dataframes/digital/digital_1975-2022.parquet")

# %%
df
# Out:
#         PT                                                 AU  \
# 0        J                                Holt, JD; Chung, SM
# 1        C                Xia, SR; Wu, AJ; Zhu, AD; Liang, XZ
# 2        C  Le Bonte, S; Pons, MN; Potier, O; Chanel, S; B...
# 3        J                                Khalil, IG; Hill, C
# 4        S                                            Chen, K
# ...     ..                                                ...
# 1253123  J                                  Wei, FF; Feng, JQ
# 1253124  C  Hu, Y; Huang, XM; Baker, AH; Tseng, YH; Bryan,...
# 1253125  J                          Kim, TJ; Sun, X; Yoon, SE
# 1253126  J                       Kavouklis, C; Kallinderis, Y
# 1253127  J                  Zhao, B; Liu, Y; Goh, SH; Lee, FH
#
#                                                         TI  \
# 0        Mining association rules using inverted hashin...
# 1        An efficient & low-cost methodology for comput...
# ...

# %%
df.groupby('PY').PT.count().plot()
# Out:
# <AxesSubplot:xlabel='PY'>
