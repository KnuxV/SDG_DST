# %%
import pandas as pd
df = pd.read_pickle("../data/output/WoS_SDG_updated.pkl")

# %%
df
# Out:
#         PT                                                 AU  \
# 0        C                            Das, S; Mukhopadhyay, P
# 1        J                                             Das, T
# 2        J  Paulson, K; Brazauskas, R; Khera, N; He, N; Ma...
# 3        J          Sudharsanan, N; Romano, S; Cunningham, SA
# 4        J                                    Abdel-Rahman, O
# ...     ..                                                ...
# 1202013  C                                    Yin, S; Liu, YS
# 1202014  J         Yuan, JF; Skibniewski, MJ; Li, QM; Shan, J
# 1202015  C        Yuan, JF; Skibniewski, MJ; Li, QM; Xiong, W
# 1202016  J                                   Zhang, Z; Jia, M
# 1202017  C                                    Zhu, CF; Li, YZ
#
#                                                         TI  \
# 0        Multi-hazard disaster resilient housing with b...
# 1        Does credit access lead to expansion of income...
# ...

# %%
df_sdg_dst = df[df['DST']]

# %%
df_sdg_dst
# Out:
#         PT                                                 AU  \
# 24       C  Kuznetsov, S; Trutoiu, LC; Kute, C; Howley, I;...
# 159      J      Duncan, JMA; Biggs, EM; Dash, J; Atkinson, PM
# 241      J                              Cuesta, J; Chagalj, C
# 274      J                                           Arora, P
# 295      J                            Petsiuk, AL; Pearce, JM
# ...     ..                                                ...
# 1201895  J                  Bost, F; Jacobs, RT; Kowalczyk, P
# 1201905  J                                        Muraguri, L
# 1201907  J  Rola, AC; Elazegui, DD; Nguyen, MR; Magdalita,...
# 1201940  J                                       Alexakis, DP
# 1202010  C                                           Welch, D
#
#                                                         TI  \
# 24       Breaking Boundaries: Strategies for Mentoring ...
# 159      Spatio-temporal trends in precipitation and th...
# ...

# %%
df_sdg_dst.to_pickle("../data/output/SDG_DST.pkl")

# %%
list(df_sdg_dst.columns[30:37])
# Out:
# ['AI',
#  'big_data',
#  'IOT',
#  'computing_infrastructure',
#  'blockchain',
#  'robotics',
#  'additive_manufacturing']

# %%
df_dst = pd.read_pickle("../data/dataframes/test.pkl")

# %%
df_dst
# Out:
#     PT                                                 AU  \
# 4    J  Pham, VT; Jafari, S; Vaidyanathan, S; Volos, C...
# 10   J  Corbaton-Baguena, MJ; Vincent-Vela, MC; Gozalv...
# 23   J                Jalal, ME; Hosseini, M; Karlsson, S
# 28   J   Saric, T; Simunovic, G; Simunovic, K; Svalina, I
# 35   J                                     Tyshchenko, OK
# ..  ..                                                ...
# 184  J  Wen, ZF; Zhang, C; Shao, GF; Wu, SJ; Atkinson, PM
# 185  J  Sydes, MR; Barbachano, Y; Bowman, L; Denwood, ...
# 186  J  Gurdasani, D; Bhatt, S; Costello, A; Denaxas, ...
# 189  J  Wang, CF; Bendle, JA; Yang, H; Yang, Y; Hardma...
# 191  J  Nasser, MG; Hosni, EM; Kenawy, MA; Alharbi, SA...
#
#                                                     TI  \
# 4    A novel memristive neural network with hidden ...
# 10   Comparison between artificial neural networks ...
# 23   Forecasting incoming call volumes in call cent...
# ...
